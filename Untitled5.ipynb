# %% [markdown]
# <a href="https://colab.research.google.com/github/Fundkdh/algorithm-2022/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #2023 3차시 팀과제
# #서울자전거데이터 머신러닝

# %% [markdown]
# #Y(종속변수): 빌린 자전거 개수
# #X(독립변수) : 습도
# #X(통제변수) : 온도 , 풍속

# %%
import pandas as pd
import numpy as np

#서울시자전거데이터 마운트트
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SeoulBikeData.csv", encoding = "cp949")
df
# Out:
#             Date  Rented Bike Count  Hour  Temperature(캜)  Humidity(%)  \
# 0     01/12/2017                254     0            -5.2           37
# 1     01/12/2017                204     1            -5.5           38
# 2     01/12/2017                173     2            -6.0           39
# 3     01/12/2017                107     3            -6.2           40
# 4     01/12/2017                 78     4            -6.0           36
# ...          ...                ...   ...             ...          ...
# 8755  30/11/2018               1003    19             4.2           34
# 8756  30/11/2018                764    20             3.4           37
# 8757  30/11/2018                694    21             2.6           39
# 8758  30/11/2018                712    22             2.1           41
# 8759  30/11/2018                584    23             1.9           43
#
#       Wind speed (m/s)  Visibility (10m)  Dew point temperature(캜)  \
# ...

# %%
from sklearn.model_selection import train_test_split # train set과 test set을 나눈다
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import accuracy_score

# %%
df.columns
# Out:
# Index(['Date', 'Rented Bike Count', 'Hour', 'Temperature(캜)', 'Humidity(%)',
#        'Wind speed (m/s)', 'Visibility (10m)', 'Dew point temperature(캜)',
#        'Solar Radiation (MJ/m2)', 'Rainfall(mm)', 'Snowfall (cm)', 'Seasons',
#        'Holiday', 'Functioning Day'],
#       dtype='object')

# %%
#칼럼 열 삭제제
df1 = df.drop(['Date', 'Hour', 'Visibility (10m)', 'Dew point temperature(캜)',
       'Solar Radiation (MJ/m2)', 'Rainfall(mm)', 'Snowfall (cm)', 'Seasons',
       'Holiday', 'Functioning Day'], axis = 1)

# %%
df1.columns
# Out:
# Index(['Rented Bike Count', 'Temperature(캜)', 'Humidity(%)',
#        'Wind speed (m/s)'],
#       dtype='object')

# %%
#변수 rename 
df1.rename(columns={'Rented Bike Count': '빌린 자전거 갯수', 'Temperature(캜)': '온도', 'Humidity(%)':'습도'
                    ,'Wind speed (m/s)': '풍속'},inplace=True)

# %%
df1.columns
# Out:
# Index(['빌린 자전거 갯수', '온도', '습도', '풍속'], dtype='object')

# %%
df1
# Out:
#       빌린 자전거 갯수   온도  습도   풍속
# 0           254 -5.2  37  2.2
# 1           204 -5.5  38  0.8
# 2           173 -6.0  39  1.0
# 3           107 -6.2  40  0.9
# 4            78 -6.0  36  2.3
# ...         ...  ...  ..  ...
# 8755       1003  4.2  34  2.6
# 8756        764  3.4  37  2.3
# 8757        694  2.6  39  0.3
# 8758        712  2.1  41  1.0
# 8759        584  1.9  43  1.3
#
# [8760 rows x 4 columns]

# %%
X = df1[["풍속", "습도", "온도"]]
Y = np.log1p(df1["빌린 자전거 갯수"])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=42)

# %%
df1.isnull().sum()
# Out:
# 빌린 자전거 갯수    0
# 온도           0
# 습도           0
# 풍속           0
# dtype: int64

# %%
from sklearn.svm import SVR
from math import sqrt
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import classification_report#분류모형 도표값을 출력하는 패키지지
from sklearn.metrics import mean_squared_error

scaler = StandardScaler().fit(X_train, Y_train)
X_test = scaler.transform(X_test)
X_train = scaler.transform(X_train)


SVR_model = SVR(C=1, kernel = "linear", epsilon=0.1)
SVR_model.fit(X_train, Y_train)
Y_pred = SVR_model.predict(X_test)
print("accuracy:{:.3f}".format(rmse))
rmse = sqrt(mean_squared_error(Y_test, Y_pred))
print("RMSE: {:.3f}".format(rmse))
print(SVR_model.coef_)
# Out:
# accuracy:1.389
# RMSE: 1.389
# [[ 0.01303542 -0.34945567  0.72286966]]
